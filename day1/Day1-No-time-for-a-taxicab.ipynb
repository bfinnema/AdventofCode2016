# %%
def find_direction(x, dir):
    if dir == [1,0]:
        if x[0] == "L":
            return [0,-1]
        if x[0] == "R":
            return [0,1]
    if dir == [0,1]:
        if x[0] == "L":
            return [1,0]
        if x[0] == "R":
            return [-1,0]
    if dir == [-1,0]:
        if x[0] == "L":
            return [0,1]
        if x[0] == "R":
            return [0,-1]
    if dir == [0,-1]:
        if x[0] == "L":
            return [-1,0]
        if x[0] == "R":
            return [1,0]

def check_visited_places(place):
    for p in visited_places:
        if p == place:
            print "You have already visited %s, %s before. %s, %s" %(place[0],place[1],p[0],p[1])
            print "It is %s blocks away" %(abs(place[0])+abs(place[1]))
    visited_places.append(place)

path_file = open('bunnypath.txt')
path_str = path_file.read()

bunnypath = path_str.split(', ')

visited_places = [[0,0]]
latitude = 0
longitude = 0
direction = [1,0]

for x in bunnypath:
    direction = find_direction(x, direction)
    new_length = int(x[1:])
    i = 0
    while i < new_length:
        latitude = latitude + direction[0]
        longitude = longitude + direction[1]
        check_visited_places([latitude,longitude])
        i += 1
    #print "x is %s. Direction is %s, %s. Latitude is %s. Longitude is %s" %(x, direction[0], direction[1], latitude, longitude)
    
hq_distance = abs(latitude) + abs (longitude)
print "Easter Bunny HQ is %s blocks away" %hq_distance
# Out:
# You have already visited 8, -158 before. 8, -158
# It is 166 blocks away
# You have already visited -146, -169 before. -146, -169
# It is 315 blocks away
# You have already visited -145, -169 before. -145, -169
# It is 314 blocks away
# You have already visited -145, -168 before. -145, -168
# It is 313 blocks away
# You have already visited -145, -167 before. -145, -167
# It is 312 blocks away
# You have already visited -145, -166 before. -145, -166
# It is 311 blocks away
# You have already visited -145, -161 before. -145, -161
# It is 306 blocks away
# You have already visited -145, -160 before. -145, -160
# It is 305 blocks away
# You have already visited -145, -159 before. -145, -159
# It is 304 blocks away
# You have already visited -147, -159 before. -147, -159
# It is 306 blocks away
# You have already visited -147, -161 before. -147, -161
# It is 308 blocks away
# You have already visited -146, -161 before. -146, -161
# It is 307 blocks away
# You have already visited -146, -159 before. -146, -159
# It is 305 blocks away
# You have already visited -147, -158 before. -147, -158
# It is 305 blocks away
# You have already visited -147, -159 before. -147, -159
# It is 306 blocks away
# You have already visited -147, -159 before. -147, -159
# It is 306 blocks away
# You have already visited -147, -160 before. -147, -160
# It is 307 blocks away
# You have already visited -146, -160 before. -146, -160
# It is 306 blocks away
# You have already visited -145, -160 before. -145, -160
# It is 305 blocks away
# You have already visited -145, -160 before. -145, -160
# It is 305 blocks away
# You have already visited -143, -158 before. -143, -158
# It is 301 blocks away
# You have already visited -147, -157 before. -147, -157
# It is 304 blocks away
# You have already visited -147, -158 before. -147, -158
# It is 305 blocks away
# You have already visited -147, -158 before. -147, -158
# It is 305 blocks away
# You have already visited -147, -159 before. -147, -159
# It is 306 blocks away
# You have already visited -147, -159 before. -147, -159
# It is 306 blocks away
# You have already visited -147, -159 before. -147, -159
# It is 306 blocks away
# You have already visited -147, -160 before. -147, -160
# It is 307 blocks away
# You have already visited -147, -160 before. -147, -160
# It is 307 blocks away
# You have already visited -147, -161 before. -147, -161
# It is 308 blocks away
# You have already visited -147, -161 before. -147, -161
# It is 308 blocks away
# You have already visited -146, -161 before. -146, -161
# It is 307 blocks away
# You have already visited -146, -161 before. -146, -161
# It is 307 blocks away
# You have already visited -145, -161 before. -145, -161
# It is 306 blocks away
# You have already visited -145, -161 before. -145, -161
# It is 306 blocks away
# You have already visited -145, -162 before. -145, -162
# It is 307 blocks away
# You have already visited -145, -164 before. -145, -164
# It is 309 blocks away
# You have already visited -145, -165 before. -145, -165
# It is 310 blocks away
# You have already visited -145, -166 before. -145, -166
# It is 311 blocks away
# You have already visited -145, -166 before. -145, -166
# It is 311 blocks away
# You have already visited -144, -166 before. -144, -166
# It is 310 blocks away
# You have already visited -144, -165 before. -144, -165
# It is 309 blocks away
# You have already visited -144, -164 before. -144, -164
# It is 308 blocks away
# You have already visited -145, -164 before. -145, -164
# It is 309 blocks away
# You have already visited -145, -164 before. -145, -164
# It is 309 blocks away
# You have already visited -146, -164 before. -146, -164
# It is 310 blocks away
# You have already visited -147, -164 before. -147, -164
# It is 311 blocks away
# You have already visited -148, -164 before. -148, -164
# It is 312 blocks away
# You have already visited -149, -164 before. -149, -164
# It is 313 blocks away
# You have already visited -149, -161 before. -149, -161
# It is 310 blocks away
# You have already visited -148, -161 before. -148, -161
# It is 309 blocks away
# You have already visited -147, -161 before. -147, -161
# It is 308 blocks away
# You have already visited -147, -161 before. -147, -161
# It is 308 blocks away
# You have already visited -147, -161 before. -147, -161
# It is 308 blocks away
# You have already visited -146, -161 before. -146, -161
# It is 307 blocks away
# You have already visited -146, -161 before. -146, -161
# It is 307 blocks away
# You have already visited -146, -161 before. -146, -161
# It is 307 blocks away
# You have already visited -145, -161 before. -145, -161
# It is 306 blocks away
# You have already visited -145, -161 before. -145, -161
# It is 306 blocks away
# You have already visited -145, -161 before. -145, -161
# It is 306 blocks away
# You have already visited -145, -160 before. -145, -160
# It is 305 blocks away
# You have already visited -145, -160 before. -145, -160
# It is 305 blocks away
# You have already visited -145, -160 before. -145, -160
# It is 305 blocks away
# You have already visited -144, -160 before. -144, -160
# It is 304 blocks away
# You have already visited -143, -160 before. -143, -160
# It is 303 blocks away
# You have already visited -131, -158 before. -131, -158
# It is 289 blocks away
# You have already visited -128, -158 before. -128, -158
# It is 286 blocks away
# You have already visited -131, -161 before. -131, -161
# It is 292 blocks away
# You have already visited -132, -162 before. -132, -162
# It is 294 blocks away
# You have already visited -129, -168 before. -129, -168
# It is 297 blocks away
# You have already visited -144, -160 before. -144, -160
# It is 304 blocks away
# You have already visited -144, -160 before. -144, -160
# It is 304 blocks away
# You have already visited -145, -160 before. -145, -160
# It is 305 blocks away
# You have already visited -145, -160 before. -145, -160
# It is 305 blocks away
# You have already visited -145, -160 before. -145, -160
# It is 305 blocks away
# You have already visited -145, -160 before. -145, -160
# It is 305 blocks away
# You have already visited -146, -160 before. -146, -160
# It is 306 blocks away
# You have already visited -146, -160 before. -146, -160
# It is 306 blocks away
# You have already visited -147, -160 before. -147, -160
# It is 307 blocks away
# You have already visited -147, -160 before. -147, -160
# It is 307 blocks away
# You have already visited -147, -160 before. -147, -160
# It is 307 blocks away
# You have already visited -148, -161 before. -148, -161
# It is 309 blocks away
# You have already visited -148, -161 before. -148, -161
# It is 309 blocks away
# You have already visited -148, -164 before. -148, -164
# It is 312 blocks away
# You have already visited -148, -164 before. -148, -164
# It is 312 blocks away
# You have already visited -149, -164 before. -149, -164
# It is 313 blocks away
# You have already visited -149, -164 before. -149, -164
# It is 313 blocks away
# You have already visited -150, -164 before. -150, -164
# It is 314 blocks away
# You have already visited -148, -164 before. -148, -164
# It is 312 blocks away
# You have already visited -148, -164 before. -148, -164
# It is 312 blocks away
# You have already visited -148, -164 before. -148, -164
# It is 312 blocks away
# You have already visited -149, -164 before. -149, -164
# It is 313 blocks away
# You have already visited -149, -164 before. -149, -164
# It is 313 blocks away
# You have already visited -149, -164 before. -149, -164
# It is 313 blocks away
# You have already visited -150, -164 before. -150, -164
# It is 314 blocks away
# You have already visited -150, -164 before. -150, -164
# It is 314 blocks away
# You have already visited -151, -164 before. -151, -164
# It is 315 blocks away
# You have already visited -150, -162 before. -150, -162
# It is 312 blocks away
# You have already visited -150, -161 before. -150, -161
# It is 311 blocks away
# You have already visited -153, -162 before. -153, -162
# It is 315 blocks away
# You have already visited -155, -163 before. -155, -163
# It is 318 blocks away
# You have already visited -155, -164 before. -155, -164
# It is 319 blocks away
# You have already visited -155, -165 before. -155, -165
# It is 320 blocks away
# You have already visited -151, -166 before. -151, -166
# It is 317 blocks away
# You have already visited -150, -166 before. -150, -166
# It is 316 blocks away
# Easter Bunny HQ is 332 blocks away
# [[0, 0], [0, -1], [0, -2], [0, -3], [0, -4], [-1, -4], [-2, -4], [-3, -4], [-3, -5], [-4, -5], [-5, -5], [-6, -5], [-7, -5], [-7, -6], [-7, -7], [-6, -7], [-5, -7], [-5, -8], [-6, -8], [-7, -8], [-7, -9], [-6, -9], [-6, -10], [-6, -11], [-6, -12], [-5, -12], [-4, -12], [-3, -12], [-2, -12], [-1, -12], [-1, -13], [-1, -14], [0, -14], [1, -14], [2, -14], [3, -14], [4, -14], [4, -15], [4, -16], [4, -17], [4, -18], [3, -18], [2, -18], [1, -18], [1, -19], [1, -20], [2, -20], [3, -20], [3, -21], [3, -22], [3, -23], [3, -24], [3, -25], [2, -25], [2, -26], [2, -27], [2, -28], [2, -29], [1, -29], [1, -30], [1, -31], [1, -32], [0, -32], [-1, -32], [-2, -32], [-2, -33], [-2, -34], [-2, -35], [-2, -36], [-2, -37], [-1, -37], [0, -37], [0, -38], [0, -39], [0, -40], [0, -41], [0, -42], [1, -42], [2, -42], [2, -41], [1, -41], [1, -40], [1, -39], [1, -38], [1, -37], [1, -36], [0, -36], [0, -35], [0, -34], [0, -33], [1, -33], [2, -33], [2, -34], [2, -35], [2, -36], [2, -37], [2, -38], [3, -38], [4, -38], [5, -38], [6, -38], [6, -37], [6, -36], [6, -35], [6, -34], [7, -34], [8, -34], [8, -35], [7, -35], [7, -36], [8, -36], [8, -37], [8, -38], [8, -39], [8, -40], [8, -41], [8